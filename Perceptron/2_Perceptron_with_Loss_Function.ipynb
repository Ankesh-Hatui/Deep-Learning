# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
x,y= make_classification(
    n_samples=100,
    n_features=2,
    n_classes=2,
    n_informative=1,
    n_clusters_per_class=1,
    n_redundant=0,
    random_state=999
)

# %%
x.shape
# Out:
# (100, 2)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
epochs = 1000
def Perceptron(x,y):
  w1=w2=b = 1
  learning_rate = 0.1
  for _ in range(epochs):

    for i in range(x.shape[0]):
      fx = w1*x[i][0] + w2*x[i][1] + b
      fun = y[i]*fx

      if fun <0:
        w1 = w1 + learning_rate*(-y[i]*x[i][0])
        w2 = w2 + learning_rate * (-y[i]* x[i][1])
        b =  b  + learning_rate*(-y[i])
  return (w1,w2,b)

# %%
w1,w2,b = Perceptron(x,y)
print (w1,w2,b)
# Out:
# -5372.825729431684 287.87970978235563 -4890.50000000026

# %%
x_input= np.linspace(-3,3,100) # this will cretae 100 points in range [-3,3]
m=-(w1/w2)
c=-(b/w2)
y_input= x_input*m + c
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,3)
# Out:
# (-3.0, 3.0)
